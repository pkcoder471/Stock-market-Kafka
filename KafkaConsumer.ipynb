# %%
pip install s3fs
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from kafka import KafkaConsumer
from time import sleep 
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer('demo_test', 
                         bootstrap_servers = ['13.61.190.230:9092'],
                         value_deserializer = lambda x:
                         loads(x.decode('utf-8')))

# %%
for c in consumer:
    print(c.value)
# Out:
# {'Index': 'IXIC', 'Date': '2013-12-19', 'Open': 4059.340088, 'High': 4063.699951, 'Low': 4045.409912, 'Close': 4058.139893, 'Adj Close': 4058.139893, 'Volume': 1813050000.0, 'CloseUSD': 4058.139893}
# {'Index': 'NYA', 'Date': '1969-05-29', 'Open': 611.900024, 'High': 611.900024, 'Low': 611.900024, 'Close': 611.900024, 'Adj Close': 611.900024, 'Volume': 0.0, 'CloseUSD': 611.900024}
# {'Index': 'NYA', 'Date': '2008-11-28', 'Open': 5547.379883, 'High': 5599.299805, 'Low': 5492.799805, 'Close': 5599.299805, 'Adj Close': 5599.299805, 'Volume': 2740860000.0, 'CloseUSD': 5599.299805}
# {'Index': 'SSMI', 'Date': '1992-06-24', 'Open': 1846.599976, 'High': 1846.599976, 'Low': 1828.5, 'Close': 1838.300049, 'Adj Close': 1838.300049, 'Volume': 0.0, 'CloseUSD': 2040.51305439}
# {'Index': 'N225', 'Date': '2020-04-15', 'Open': 19589.25, 'High': 19660.67969, 'Low': 19465.94922, 'Close': 19550.08984, 'Adj Close': 19550.08984, 'Volume': 94100000.0, 'CloseUSD': 195.5008984}
# {'Index': 'NYA', 'Date': '1984-04-12', 'Open': 958.400024, 'High': 958.400024, 'Low': 958.400024, 'Close': 958.400024, 'Adj Close': 958.400024, 'Volume': 0.0, 'CloseUSD': 958.400024}
# {'Index': 'NYA', 'Date': '1990-12-26', 'Open': 1909.619995, 'High': 1909.619995, 'Low': 1909.619995, 'Close': 1909.619995, 'Adj Close': 1909.619995, 'Volume': 0.0, 'CloseUSD': 1909.619995}
# {'Index': 'GDAXI', 'Date': '2003-11-12', 'Open': 3730.139893, 'High': 3754.350098, 'Low': 3696.949951, 'Close': 3748.340088, 'Adj Close': 3748.340088, 'Volume': 126514600.0, 'CloseUSD': 4572.97490736}
# {'Index': 'GDAXI', 'Date': '2009-05-14', 'Open': 4727.680176, 'High': 4744.620117, 'Low': 4653.25, 'Close': 4738.470215, 'Adj Close': 4738.470215, 'Volume': 126281500.0, 'CloseUSD': 5780.9336623}
# {'surname': 'Kashyap'}
# {'Index': 'IXIC', 'Date': '1998-07-13', 'Open': 1948.319946, 'High': 1965.719971, 'Low': 1946.630005, 'Close': 1965.530029, 'Adj Close': 1965.530029, 'Volume': 776950000.0, 'CloseUSD': 1965.530029}
# {'Index': 'TWII', 'Date': '2001-04-24', 'Open': 5569.620117, 'High': 5644.680176, 'Low': 5567.430176, 'Close': 5589.339844, 'Adj Close': 5589.318848, 'Volume': 0.0, 'CloseUSD': 223.57359376}
# {'Index': 'GDAXI', 'Date': '2000-02-25', 'Open': 7668.700195, 'High': 7776.839844, 'Low': 7640.689941, 'Close': 7738.680176, 'Adj Close': 7738.680176, 'Volume': 34635700.0, 'CloseUSD': 9441.18981472}
# {'Index': 'IXIC', 'Date': '1992-09-16', 'Open': 583.400024, 'High': 588.030029, 'Low': 582.159973, 'Close': 585.890015, 'Adj Close': 585.890015, 'Volume': 181510000.0, 'CloseUSD': 585.890015}
# {'Index': 'GDAXI', 'Date': '1988-04-20', 'Open': 1075.76001, 'High': 1075.76001, 'Low': 1075.76001, 'Close': 1075.76001, 'Adj Close': 1075.76001, 'Volume': 0.0, 'CloseUSD': 1312.4272122}
# {'Index': 'HSI', 'Date': '1989-03-15', 'Open': 3095.899902, 'High': 3095.899902, 'Low': 3095.899902, 'Close': 3095.899902, 'Adj Close': 3095.899902, 'Volume': 0.0, 'CloseUSD': 402.46698726000005}
# {'Index': 'GSPTSE', 'Date': '1989-03-08', 'Open': 3619.0, 'High': 3640.600098, 'Low': 3619.0, 'Close': 3632.399902, 'Adj Close': 3623.175537, 'Volume': 24910000.0, 'CloseUSD': 3014.89191866}
# {'Index': 'GDAXI', 'Date': '2011-10-17', 'Open': 6021.290039, 'High': 6081.410156, 'Low': 5819.970215, 'Close': 5859.430176, 'Adj Close': 5859.430176, 'Volume': 177500100.0, 'CloseUSD': 7148.50481472}
# {'Index': 'GDAXI', 'Date': '2015-02-05', 'Open': 10840.79004, 'High': 10926.73047, 'Low': 10822.75, 'Close': 10905.41016, 'Adj Close': 10905.41016, 'Volume': 87662700.0, 'CloseUSD': 13304.6003952}
# {'Index': 'N100', 'Date': '2015-05-13', 'Open': 978.469971, 'High': 987.090027, 'Low': 970.409973, 'Close': 973.530029, 'Adj Close': 973.530029, 'Volume': 515257600.0, 'CloseUSD': 1187.70663538}
# {'Index': 'HSI', 'Date': '2001-08-15', 'Open': 12031.08984, 'High': 12156.87988, 'Low': 11897.46973, 'Close': 12141.62988, 'Adj Close': 12141.62988, 'Volume': 191067400.0, 'CloseUSD': 1578.4118844000002}
# {'Index': 'NSEI', 'Date': '2018-04-05', 'Open': 10228.4502, 'High': 10331.79981, 'Low': 10227.4502, 'Close': 10325.15039, 'Adj Close': 10325.15039, 'Volume': 236800.0, 'CloseUSD': 103.2515039}
# {'Index': 'N225', 'Date': '2014-11-18', 'Open': 17188.83984, 'High': 17356.75977, 'Low': 17186.5, 'Close': 17344.06055, 'Adj Close': 17344.06055, 'Volume': 158100000.0, 'CloseUSD': 173.44060549999998}
# {'Index': 'IXIC', 'Date': '2010-11-02', 'Open': 2525.939941, 'High': 2534.879883, 'Low': 2518.290039, 'Close': 2533.52002, 'Adj Close': 2533.52002, 'Volume': 1914980000.0, 'CloseUSD': 2533.52002}
# {'Index': 'NYA', 'Date': '1972-05-01', 'Open': 628.710022, 'High': 628.710022, 'Low': 628.710022, 'Close': 628.710022, 'Adj Close': 628.710022, 'Volume': 0.0, 'CloseUSD': 628.710022}
# {'Index': 'TWII', 'Date': '2006-11-22', 'Open': 7330.009766, 'High': 7350.629883, 'Low': 7314.359863, 'Close': 7348.77002, 'Adj Close': 7348.742188, 'Volume': 4604400.0, 'CloseUSD': 293.9508008}
# {'Index': '000001.SS', 'Date': '2015-10-30', 'Open': 3380.283936, 'High': 3417.200928, 'Low': 3346.591064, 'Close': 3382.561035, 'Adj Close': 3382.561035, 'Volume': 243600.0, 'CloseUSD': 541.2097656000001}
# {'Index': 'GSPTSE', 'Date': '2016-08-03', 'Open': 14477.5, 'High': 14523.90039, 'Low': 14439.79981, 'Close': 14512.09961, 'Adj Close': 14512.09961, 'Volume': 17876270000.0, 'CloseUSD': 12045.0426763}
# {'Index': 'NYA', 'Date': '2009-05-20', 'Open': 5872.22998, 'High': 6002.180176, 'Low': 5859.450195, 'Close': 5870.390137, 'Adj Close': 5870.390137, 'Volume': 8205060000.0, 'CloseUSD': 5870.390137}
# {'Index': '000001.SS', 'Date': '2007-08-24', 'Open': 5070.650879, 'High': 5125.358887, 'Low': 5052.241211, 'Close': 5107.667969, 'Adj Close': 5107.667969, 'Volume': 109000.0, 'CloseUSD': 817.22687504}
# {'Index': 'N225', 'Date': '1994-03-14', 'Open': 20157.7207, 'High': 20580.96094, 'Low': 20157.7207, 'Close': 20526.15039, 'Adj Close': 20526.15039, 'Volume': 0.0, 'CloseUSD': 205.2615039}
# {'Index': 'NYA', 'Date': '1970-11-17', 'Open': 479.309998, 'High': 479.309998, 'Low': 479.309998, 'Close': 479.309998, 'Adj Close': 479.309998, 'Volume': 0.0, 'CloseUSD': 479.309998}
# {'Index': 'IXIC', 'Date': '1978-09-05', 'Open': 135.460007, 'High': 135.460007, 'Low': 135.460007, 'Close': 135.460007, 'Adj Close': 135.460007, 'Volume': 0.0, 'CloseUSD': 135.460007}
# {'Index': 'J203.JO', 'Date': '2013-01-08', 'Open': 40162.55859, 'High': 40256.23828, 'Low': 40055.83984, 'Close': 40155.62109, 'Adj Close': 40155.62109, 'Volume': 0.0, 'CloseUSD': 2810.8934763}
# {'Index': 'N225', 'Date': '2012-03-08', 'Open': 9674.94043, 'High': 9768.959961, 'Low': 9659.150391, 'Close': 9768.959961, 'Adj Close': 9768.959961, 'Volume': 144100000.0, 'CloseUSD': 97.68959961}
# {'Index': 'NYA', 'Date': '2008-10-29', 'Open': 5733.490234, 'High': 5998.709961, 'Low': 5692.350098, 'Close': 5774.890137, 'Adj Close': 5774.890137, 'Volume': 7077800000.0, 'CloseUSD': 5774.890137}
# {'Index': 'NSEI', 'Date': '2014-09-11', 'Open': 8115.149902, 'High': 8127.950195, 'Low': 8057.299805, 'Close': 8085.700195, 'Adj Close': 8085.700195, 'Volume': 122800.0, 'CloseUSD': 80.85700195000001}
# {'Index': 'N100', 'Date': '2006-12-20', 'Open': 959.169983, 'High': 960.890015, 'Low': 957.75, 'Close': 958.400024, 'Adj Close': 958.400024, 'Volume': 237502700.0, 'CloseUSD': 1169.24802928}
# {'Index': 'N225', 'Date': '1992-01-09', 'Open': 22736.84961, 'High': 23114.53906, 'Low': 22544.33984, 'Close': 23113.64063, 'Adj Close': 23113.64063, 'Volume': 0.0, 'CloseUSD': 231.13640630000003}
# {'Index': '399001.SZ', 'Date': '2017-05-11', 'Open': 9704.879883, 'High': 9776.509766, 'Low': 9566.419922, 'Close': 9776.450195, 'Adj Close': 9776.34082, 'Volume': 821600.0, 'CloseUSD': 1564.2320312}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 for c in consumer:
#       2     print(c.value)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:1190, in KafkaConsumer.__next__(self)
#    1188     self._iterator = self._message_generator_v2()
#    1189 try:
# -> 1190     return next(self._iterator)
#    1191 except StopIteration:
#    1192     self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:1162, in KafkaConsumer._message_generator_v2(self)
#    1160 def _message_generator_v2(self):
#    1161     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1162     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1163     for tp, records in six.iteritems(record_map):
#    1164         # Generators are stateful, and it is possible that the tp / records
#    1165         # here may become stale during iteration -- i.e., we seek to a
#    1166         # different offset, pause consumption, or lose assignment.
#    1167         for record in records:
#    1168             # is_fetchable(tp) should handle assignment changes and offset
#    1169             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1170             # outer function destroying the existing iterator/generator
#    1171             # via self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     683 while not self._closed:
# --> 684     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:730, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     727 if not has_all_fetch_positions:
#     728     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 730 self._client.poll(timeout_ms=poll_timeout_ms)
#     731 # after the long poll, we should check whether the group needs to rebalance
#     732 # prior to returning data so that the group can stabilize faster
#     733 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\client_async.py:689, in KafkaClient.poll(self, timeout_ms, future)
#     682         timeout = min(
#     683             user_timeout_ms,
#     684             metadata_timeout_ms,
#     685             idle_connection_timeout_ms,
#     686             request_timeout_ms)
#     687         timeout = max(0, timeout)  # avoid negative timeouts
# --> 689     self._poll(timeout / 1000)
#     691 # called without the lock to avoid deadlock potential
#     692 # if handlers need to acquire locks
#     693 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\client_async.py:732, in KafkaClient._poll(self, timeout)
#     729 self._register_send_sockets()
#     731 start_select = time.time()
# --> 732 ready = self._selector.select(timeout)
#     733 end_select = time.time()
#     734 if self._sensors:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\AppData\Local\Programs\Python\Python39\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-project-prateek/stock_market_{}.json".format(count), 'w') as file:
                 json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stock-market-project-prateek/stock_market_{}.json".format(count), 'w') as file:
#       3                  json.dump(i.value, file)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:1190, in KafkaConsumer.__next__(self)
#    1188     self._iterator = self._message_generator_v2()
#    1189 try:
# -> 1190     return next(self._iterator)
#    1191 except StopIteration:
#    1192     self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:1162, in KafkaConsumer._message_generator_v2(self)
#    1160 def _message_generator_v2(self):
#    1161     timeout_ms = 1000 * max(0, self._consumer_timeout - time.time())
# -> 1162     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1163     for tp, records in six.iteritems(record_map):
#    1164         # Generators are stateful, and it is possible that the tp / records
#    1165         # here may become stale during iteration -- i.e., we seek to a
#    1166         # different offset, pause consumption, or lose assignment.
#    1167         for record in records:
#    1168             # is_fetchable(tp) should handle assignment changes and offset
#    1169             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1170             # outer function destroying the existing iterator/generator
#    1171             # via self._iterator = None
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:684, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     682 inner_timeout_ms = timeout_ms_fn(timeout_ms, None)
#     683 while not self._closed:
# --> 684     records = self._poll_once(inner_timeout_ms(), max_records, update_offsets=update_offsets)
#     685     if records:
#     686         return records
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\consumer\group.py:730, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     727 if not has_all_fetch_positions:
#     728     poll_timeout_ms = min(poll_timeout_ms, self.config['retry_backoff_ms'])
# --> 730 self._client.poll(timeout_ms=poll_timeout_ms)
#     731 # after the long poll, we should check whether the group needs to rebalance
#     732 # prior to returning data so that the group can stabilize faster
#     733 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\client_async.py:689, in KafkaClient.poll(self, timeout_ms, future)
#     682         timeout = min(
#     683             user_timeout_ms,
#     684             metadata_timeout_ms,
#     685             idle_connection_timeout_ms,
#     686             request_timeout_ms)
#     687         timeout = max(0, timeout)  # avoid negative timeouts
# --> 689     self._poll(timeout / 1000)
#     691 # called without the lock to avoid deadlock potential
#     692 # if handlers need to acquire locks
#     693 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\kafka\client_async.py:732, in KafkaClient._poll(self, timeout)
#     729 self._register_send_sockets()
#     731 start_select = time.time()
# --> 732 ready = self._selector.select(timeout)
#     733 end_select = time.time()
#     734 if self._sensors:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File ~\AppData\Local\Programs\Python\Python39\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
